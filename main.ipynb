# %%
import ultralytics
from ultralytics import YOLO

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.121 🚀 Python-3.9.11 torch-2.0.0 CPU
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 224.7/228.3 GB disk)

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 26.9MB/s]

# %%
im_path = "nighthawks.jpg"

# %%
model(im_path, show=True)
# Out:
# image 1/1 /Users/willfurtado/bbox-art/nighthawks.jpg: 352x640 4 persons, 1 bench, 37.5ms
# Speed: 2.9ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...

# %%
pose_model = YOLO('yolov8n-pose.pt')
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 6.49M/6.49M [00:00<00:00, 10.4MB/s]

# %%
pose_model("soccer.jpg", show=True)
# Out:
# image 1/1 /Users/willfurtado/bbox-art/soccer.jpg: 448x640 4 persons, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: ultralytics.yolo.engine.results.Keypoints object
#  keys: ['boxes', 'keypoints']
#  masks: None
#  names: {0: 'person'}
#  orig_img: array([[[ 25,  30,  31],
#          [ 28,  33,  34],
#          [ 28,  36,  36],
#          ...,
#          [ 34,  39,  94],
#          [ 37,  42,  97],
#          [ 39,  44,  99]],
#
#         [[ 29,  34,  35],
#          [ 30,  35,  36],
#          [ 29,  34,  35],
#          ...,
#          [ 34,  39,  94],
#          [ 37,  42,  97],
#          [ 37,  44,  99]],
#
#         [[ 28,  32,  33],
#          [ 27,  32,  33],
#          [ 26,  31,  32],
#          ...,
#          [ 32,  39,  94],
#          [ 35,  42,  97],
# ...

# %%
seg = YOLO('yolov8n-seg.pt')
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 6.73M/6.73M [00:00<00:00, 14.7MB/s]

# %%
seg("soccer.jpg", show=True)
# Out:
# image 1/1 /Users/willfurtado/bbox-art/soccer.jpg: 448x640 5 persons, 1 sports ball, 67.0ms
# Speed: 1.9ms preprocess, 67.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes', 'masks']
#  masks: ultralytics.yolo.engine.results.Masks object
# ...

# %%
pose_model.predict(source="0")
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 1280x720 at 30.00 FPS)
#
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 1 person, 56.1ms
# 0: 384x640 1 person, 42.3ms
# 0: 384x640 1 person, 49.4ms
# 0: 384x640 1 person, 43.5ms
# 0: 384x640 1 person, 43.0ms
# 0: 384x640 1 person, 42.3ms
# 0: 384x640 1 person, 42.0ms
# 0: 384x640 1 person, 42.8ms
# 0: 384x640 1 person, 42.3ms
# 0: 384x640 1 person, 46.2ms
# 0: 384x640 1 person, 40.1ms
# 0: 384x640 1 person, 39.6ms
# ...

# %%
from ultralytics import SAM

model = SAM('sam_b.pt')
model.info()  # display model information
model.predict('nighthawks.jpg')  # predict
# Out:
# ...
#   1%|▋                                                                                                     | 2.41M/358M [00:00<00:14, 25.2MB/s]
